# %% [markdown]
# # Predict - Python Data Structures

# %% [markdown]
# This is the project on Python Data Structures. We will start by transforming the raw data for you. You then need to create 9 functions as specified in the project instructions.
#
# NB: Make sure the football_players.csv file is in the same directory as this notebook
#
# **PROJECT RULES**:
#
# * You may not import any external packages (except for pandas) - all of the functions need to be solved WITHOUT THE USE OF ANY OTHER EXTERNAL MODULES.
# * Most importantly: your functions need to return the answer (not just print it out).
# * Do not add or remove any cells from this notebook. Use another notebook to experiment in (or in which to do your workings), but your submission may not have any additional cells or functions.
# * Only fill in code where the #YOUR CODE tags appear. No code outside these areas (or outside the given functions) will be marked.

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

# Load data - pass 'Name' as our index column
load_df = pd.read_csv('football_players.csv', index_col='Name').sample(frac=1)

# Create dataframe called df
df = pd.DataFrame(load_df)
# Out:
# C:\Users\BCX-JHB20\.conda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Create Position Type Column

# %%
def position_type(s):
    
    """This function converts the individual positions (abbreviations) and classfies it
    as either a forward, midfielder, back or goal keeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# Create position type column
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# %% [markdown]
# ### Transform Attribute Columns to Floats

# %%
# Select all attribute columns
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

def to_float(x):    
    "Transforms attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

df[cols] = df[cols].applymap(to_float)

# %% [markdown]
# ## Function 1
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age (max_age)

# %%
### START FUNCTION 1

def best_defender_1(rank, max_age):
    # YOUR CODE HERE
    defender = (df['Preferred Positions Type'] == 'Back')
    defender = defender.reset_index()
    defender.sort_values(['Overall', 'Name'], ascending=False,inplace=True)
    defender = defender.set_index('Name')
    
    return (defender[(defender['Age'] <= max_age)]).iloc[rank-1]

    
### END FUNCTION 1

# %%
best_defender_1(10, 35)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Overall'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-db032a22d8ad> in <module>()
# ----> 1 best_defender_1(10, 35)
#
# <ipython-input-4-6514e725970b> in best_defender_1(rank, max_age)
#       5     defender = (df['Preferred Positions Type'] == 'Back')
#       6     defender = defender.reset_index()
# ----> 7     defender.sort_values(['Overall', 'Name'], ascending=False,inplace=True)
#       8     defender = defender.set_index('Name')
#       9
#
# ~\.conda\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3605             keys = []
#    3606             for x in by:
# -> 3607                 k = self.xs(x, axis=other_axis).values
#    3608                 if k.ndim == 2:
#    3609                     raise ValueError('Cannot sort by duplicate column %s' %
#
# ~\.conda\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# ~\.conda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\.conda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\.conda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\.conda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\.conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Overall'

# %% [markdown]
# ## Function 2
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age (max_age)
# * Has an aggression score below a certain level (max_aggression)
# * Has a stamina score above a certain level (min_stamina)

# %%
### START FUNCTION 2

def best_defender_2(rank, max_age, max_aggression, min_stamina):
    
    # YOUR CODE HERE
    defenders = df[df['Preferred Positions Type'] == "Back"]
    
    defenders.sort_values('Overall', ascending=False, inplace=True)
    agee = defenders[(defenders['Age'] <= max_age) & (defenders['Aggression']<= max_aggression) & (defenders['Stamina'] > min_stamina)] 
    print(agee.iloc[rank])
    
    
    

### END FUNCTION 2

# %%
best_defender_2(10, 30, 80, 60)
# Out:
# Age                              27
# Nationality                 England
# Overall                          83
# Acceleration                     86
# Aggression                       78
# Agility                          70
# Balance                          72
# Ball control                     76
# Composure                        75
# Crossing                         78
# Curve                            76
# Dribbling                        77
# Finishing                        51
# Free kick accuracy               71
# GK diving                        12
# GK handling                       6
# GK kicking                       16
# GK positioning                   15
# GK reflexes                       8
# Heading accuracy                 73
# Interceptions                    78
# Jumping                          83
# Long passing                     67
# Long shots                       68
# Marking                          79
# Penalties                        63
# Positioning                      66
# Reactions                        81
# Short passing                    75
# Shot power                       86
# Sliding tackle                   83
# Sprint speed                     93
# Stamina                          90
# Standing tackle                  84
# Strength                         77
# Vision                           69
# Volleys                          57
# Preferred Positions         RWB RB
# Preferred Positions Type       Back
# Name: K. Walker, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 3
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age
# * Does not play for a certain team (team)

# %%
### START FUNCTION 3

def best_defender_3(rank, max_age, team):
    
    # YOUR CODE HERE
    
    defenders = df[df['Preferred Positions Type'] == "Back"]
    
    defenders.sort_values('Overall', ascending=False, inplace=True)
    
    best = defenders[(defenders['Age'] <= max_age) & (defenders['Nationality']!= team)] 
    
    print(best.iloc[rank])

### END FUNCTION 3

# %%
best_defender_3(10, 25, 'Argentina')
# Out:
# Age                              22
# Nationality                 Uruguay
# Overall                          83
# Acceleration                     68
# Aggression                       89
# Agility                          57
# Balance                          50
# Ball control                     56
# Composure                        73
# Crossing                         47
# Curve                            36
# Dribbling                        47
# Finishing                        37
# Free kick accuracy               44
# GK diving                         9
# GK handling                      11
# GK kicking                        7
# GK positioning                   10
# GK reflexes                      15
# Heading accuracy                 79
# Interceptions                    85
# Jumping                          90
# Long passing                     58
# Long shots                       48
# Marking                          85
# Penalties                        38
# Positioning                      24
# Reactions                        76
# Short passing                    68
# Shot power                       72
# Sliding tackle                   87
# Sprint speed                     72
# Stamina                          68
# Standing tackle                  86
# Strength                         84
# Vision                           27
# Volleys                          30
# Preferred Positions             CB
# Preferred Positions Type       Back
# Name: J. Giménez, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Function 4
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With specified attribute (attribute_name) above a threshold (min_attribute_score)

# %%
### START FUNCTION 4

def best_attacker_1(rank, attribute_name, min_attribute_score):
    
    # YOUR CODE HERE
    forwards = df[df['Preferred Positions Type'] == "Forward"]
    
    forwards.sort_values('Overall', ascending=False, inplace=True)
    best = forwards[forwards['Balance'] > min_attribute_score] 
    print(best.iloc[rank])

### END FUNCTION 4

# %%
best_attacker_1(10, 'Balance', 50)
# Out:
# Age                              28
# Nationality                   Gabon
# Overall                          88
# Acceleration                     95
# Aggression                       43
# Agility                          77
# Balance                          70
# Ball control                     82
# Composure                        84
# Crossing                         77
# Curve                            78
# Dribbling                        82
# Finishing                        88
# Free kick accuracy               74
# GK diving                         6
# GK handling                       9
# GK kicking                       15
# GK positioning                    9
# GK reflexes                       9
# Heading accuracy                 79
# Interceptions                    48
# Jumping                          77
# Long passing                     64
# Long shots                       79
# Marking                          28
# Penalties                        79
# Positioning                      89
# Reactions                        87
# Short passing                    77
# Shot power                       81
# Sliding tackle                   36
# Sprint speed                     96
# Stamina                          79
# Standing tackle                  25
# Strength                         77
# Vision                           77
# Volleys                          86
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: P. Aubameyang, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 5
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With average of specified attributes (attribute_1_name, attribute_2_name) above a threshold (min_attributes_ave)

# %%
### START FUNCTION 5

def best_attacker_2(rank, attribute_1_name, attribute_2_name, min_attributes_ave):
    
    # YOUR CODE HERE
    forwards = df[df['Preferred Positions Type'] == "Forward"]
    
    forwards.sort_values('Overall', ascending=False, inplace=True)
    best = forwards[forwards['Balance'] > min_attributes_ave & (forwards['Finishing'] > min_attributes_ave )] 
    print(best.iloc[rank])
### END FUNCTION 5

# %%
best_attacker_2(10, 'Finishing', 'Balance', 80)
# Out:
# Age                              28
# Nationality                   Gabon
# Overall                          88
# Acceleration                     95
# Aggression                       43
# Agility                          77
# Balance                          70
# Ball control                     82
# Composure                        84
# Crossing                         77
# Curve                            78
# Dribbling                        82
# Finishing                        88
# Free kick accuracy               74
# GK diving                         6
# GK handling                       9
# GK kicking                       15
# GK positioning                    9
# GK reflexes                       9
# Heading accuracy                 79
# Interceptions                    48
# Jumping                          77
# Long passing                     64
# Long shots                       79
# Marking                          28
# Penalties                        79
# Positioning                      89
# Reactions                        87
# Short passing                    77
# Shot power                       81
# Sliding tackle                   36
# Sprint speed                     96
# Stamina                          79
# Standing tackle                  25
# Strength                         77
# Vision                           77
# Volleys                          86
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: P. Aubameyang, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 6
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With minimum of specified attributes (attribute_1_name, attribute_2_name) above a threshold (min_attributes_min)

# %%
### START FUNCTION 6

def best_attacker_3(rank, attribute_1_name, attribute_2_name, min_attributes_min):
    
    # YOUR CODE HERE
    forwards = df[df['Preferred Positions Type'] == "Forward"]
        
    forwards.sort_values('Overall', ascending=False, inplace=True)
    best = forwards[forwards['Balance'] > min_attributes_min & (forwards['Composure'] > min_attributes_min )] 
    print(best.iloc[rank])
    
    
### END FUNCTION 6

# %%
best_attacker_3(10, 'Balance', 'Composure', 70)
# Out:
# Age                              28
# Nationality                   Gabon
# Overall                          88
# Acceleration                     95
# Aggression                       43
# Agility                          77
# Balance                          70
# Ball control                     82
# Composure                        84
# Crossing                         77
# Curve                            78
# Dribbling                        82
# Finishing                        88
# Free kick accuracy               74
# GK diving                         6
# GK handling                       9
# GK kicking                       15
# GK positioning                    9
# GK reflexes                       9
# Heading accuracy                 79
# Interceptions                    48
# Jumping                          77
# Long passing                     64
# Long shots                       79
# Marking                          28
# Penalties                        79
# Positioning                      89
# Reactions                        87
# Short passing                    77
# Shot power                       81
# Sliding tackle                   36
# Sprint speed                     96
# Stamina                          79
# Standing tackle                  25
# Strength                         77
# Vision                           77
# Volleys                          86
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: P. Aubameyang, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 7
#
# Build an algorithm that identifies the best n (no_defenders) defenders - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)
# * Under a certain age (max_age)

# %%
### START FUNCTION 7

def best_team_1(country, no_defenders, max_age):
    
    # YOUR CODE HERE
     for item in range(no_defenders):
        defenders = df[df['Preferred Positions Type'] == "Back"] 
        defenders.sort_values('Overall', ascending=False, inplace=True)
        age = defenders[(defenders['Age'] <= max_age) & (defenders['Nationality'] == country)]
        print(age.iloc[item])
        item+=1
    
### END FUNCTION 7

# %%
best_team_1('England', 3, 30)
# Out:
# Age                              27
# Nationality                 England
# Overall                          83
# Acceleration                     86
# Aggression                       78
# Agility                          70
# Balance                          72
# Ball control                     76
# Composure                        75
# Crossing                         78
# Curve                            76
# Dribbling                        77
# Finishing                        51
# Free kick accuracy               71
# GK diving                        12
# GK handling                       6
# GK kicking                       16
# GK positioning                   15
# GK reflexes                       8
# Heading accuracy                 73
# Interceptions                    78
# Jumping                          83
# Long passing                     67
# Long shots                       68
# Marking                          79
# Penalties                        63
# Positioning                      66
# Reactions                        81
# Short passing                    75
# Shot power                       86
# Sliding tackle                   83
# Sprint speed                     93
# Stamina                          90
# Standing tackle                  84
# Strength                         77
# Vision                           69
# Volleys                          57
# Preferred Positions         RWB RB
# Preferred Positions Type       Back
# Name: K. Walker, dtype: object
# Age                              26
# Nationality                 England
# Overall                          82
# Acceleration                     80
# Aggression                       87
# Agility                          73
# Balance                          76
# Ball control                     76
# Composure                        73
# Crossing                         81
# Curve                            64
# Dribbling                        79
# Finishing                        57
# Free kick accuracy               57
# GK diving                        10
# GK handling                      11
# GK kicking                        8
# GK positioning                   13
# GK reflexes                      13
# Heading accuracy                 62
# Interceptions                    81
# Jumping                          75
# Long passing                     66
# Long shots                       69
# Marking                          82
# Penalties                        57
# Positioning                      68
# Reactions                        82
# Short passing                    76
# Shot power                       72
# Sliding tackle                   85
# Sprint speed                     81
# Stamina                          81
# Standing tackle                  84
# Strength                         74
# Vision                           73
# Volleys                          64
# Preferred Positions         LWB LB
# Preferred Positions Type       Back
# Name: D. Rose, dtype: object
# Age                                 23
# Nationality                    England
# Overall                             82
# Acceleration                        70
# Aggression                          90
# Agility                             56
# Balance                             40
# Ball control                        70
# Composure                           77
# Crossing                            67
# Curve                               54
# Dribbling                           66
# Finishing                           52
# Free kick accuracy                  77
# GK diving                           11
# GK handling                         14
# GK kicking                           6
# GK positioning                      13
# GK reflexes                          9
# Heading accuracy                    83
# Interceptions                       80
# Jumping                             77
# Long passing                        77
# Long shots                          72
# Marking                             79
# Penalties                           70
# Positioning                         53
# Reactions                           76
# Short passing                       76
# Shot power                          83
# Sliding tackle                      83
# Sprint speed                        74
# Stamina                             80
# Standing tackle                     82
# Strength                            87
# Vision                              66
# Volleys                             52
# Preferred Positions         CM CDM CB
# Preferred Positions Type          Back
# Name: E. Dier, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 8
#
# Build an algorithm that identifies the best n (no_attackers) attackers - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)
# * With a specified attribute (attribute name) above a threshold (min_attribute_score)

# %%
### START FUNCTION 8

def best_team_2(country, no_attackers, attribute_name, min_attribute_score):
    
    # YOUR CODE HERE
     for item in range(no_attackers):
            attackers = df[df['Preferred Positions Type'] == "Forward"] 
            attackers.sort_values('Overall', ascending=False, inplace=True)
            age = attackers[(attackers['Finishing'] > min_attribute_score) & (attackers['Nationality'] == country)]
            print(age.iloc[item])
            item+=1
### END FUNCTION 8

# %%
best_team_2('England', 3, 'Finishing', 60)
# Out:
# Age                              23
# Nationality                 England
# Overall                          86
# Acceleration                     68
# Aggression                       74
# Agility                          73
# Balance                          62
# Ball control                     82
# Composure                        84
# Crossing                         70
# Curve                            71
# Dribbling                        78
# Finishing                        90
# Free kick accuracy               66
# GK diving                         8
# GK handling                      10
# GK kicking                       11
# GK positioning                   14
# GK reflexes                      11
# Heading accuracy                 83
# Interceptions                    35
# Jumping                          70
# Long passing                     67
# Long shots                       84
# Marking                          41
# Penalties                        84
# Positioning                      89
# Reactions                        87
# Short passing                    75
# Shot power                       87
# Sliding tackle                   38
# Sprint speed                     74
# Stamina                          85
# Standing tackle                  36
# Strength                         86
# Vision                           75
# Volleys                          73
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: H. Kane, dtype: object
# Age                                22
# Nationality                   England
# Overall                            82
# Acceleration                       94
# Aggression                         34
# Agility                            91
# Balance                            92
# Ball control                       84
# Composure                          74
# Crossing                           73
# Curve                              64
# Dribbling                          85
# Finishing                          73
# Free kick accuracy                 49
# GK diving                          15
# GK handling                        12
# GK kicking                         12
# GK positioning                     15
# GK reflexes                         9
# Heading accuracy                   38
# Interceptions                      26
# Jumping                            60
# Long passing                       67
# Long shots                         70
# Marking                            48
# Penalties                          63
# Positioning                        81
# Reactions                          79
# Short passing                      81
# Shot power                         68
# Sliding tackle                     54
# Sprint speed                       92
# Stamina                            75
# Standing tackle                    58
# Strength                           64
# Vision                             75
# Volleys                            59
# Preferred Positions         LM RM RW
# Preferred Positions Type      Forward
# Name: R. Sterling, dtype: object
# Age                              27
# Nationality                 England
# Overall                          82
# Acceleration                     74
# Aggression                       60
# Agility                          75
# Balance                          64
# Ball control                     81
# Composure                        81
# Crossing                         62
# Curve                            62
# Dribbling                        80
# Finishing                        83
# Free kick accuracy               68
# GK diving                         7
# GK handling                      15
# GK kicking                        9
# GK positioning                    5
# GK reflexes                      13
# Heading accuracy                 73
# Interceptions                    22
# Jumping                          72
# Long passing                     62
# Long shots                       80
# Marking                          15
# Penalties                        75
# Positioning                      84
# Reactions                        82
# Short passing                    74
# Shot power                       83
# Sliding tackle                   12
# Sprint speed                     78
# Stamina                          68
# Standing tackle                  24
# Strength                         71
# Vision                           74
# Volleys                          75
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: D. Sturridge, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Function 9
#
# Build an algorithm that identifies the best team based on the team structure (no_attackers, no_defenders, no_midfielders, no_goalkeepers) - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)

# %%
### START FUNCTION 9

def best_team_3(country, no_attackers, no_defenders, no_midfielders, no_goalkeepers):
    
    # YOUR CODE HERE
     for att in range(no_attackers):
        attackers = df[df['Preferred Positions Type'] == "Forward"] 
        attackers.sort_values('Overall', ascending=False, inplace=True)
        age = attackers[(attackers['Nationality'] == country)]
        print(age.iloc[att])
        att+=1 
        
        for deff in range(no_defenders):
            defenders = df[df['Preferred Positions Type'] == "Back"] 
            defenders.sort_values('Overall', ascending=False, inplace=True)
            age = defenders[(defenders['Nationality'] == country)]
            print(age.iloc[deff])
            deff+=1 
        
        for midd in range(no_midfielders): 
            midfielders = df[df['Preferred Positions Type'] == "Midfielder"] 
            midfielders.sort_values('Overall', ascending=False, inplace=True)
            age = midfielders[(midfielders['Nationality'] == country)]
            print(age.iloc[midd])
            midd+=1
        
        for goal in range(no_goalkeepers): 
            goalkeepers = df[df['Preferred Positions Type'] == "GoalKeeper"] 
            goalkeepers.sort_values('Overall', ascending=False, inplace=True)
            age = goalkeepers[(goalkeepers['Nationality'] == country)]
            print(age.iloc[goal])
            goal+=1        
    
### END FUNCTION 9

# %%
best_team_3('England', 3, 4, 3, 1)
# Out:
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# Age                              23
# Nationality                 England
# Overall                          86
# Acceleration                     68
# Aggression                       74
# Agility                          73
# Balance                          62
# Ball control                     82
# Composure                        84
# Crossing                         70
# Curve                            71
# Dribbling                        78
# Finishing                        90
# Free kick accuracy               66
# GK diving                         8
# GK handling                      10
# GK kicking                       11
# GK positioning                   14
# GK reflexes                      11
# Heading accuracy                 83
# Interceptions                    35
# Jumping                          70
# Long passing                     67
# Long shots                       84
# Marking                          41
# Penalties                        84
# Positioning                      89
# Reactions                        87
# Short passing                    75
# Shot power                       87
# Sliding tackle                   38
# Sprint speed                     74
# Stamina                          85
# Standing tackle                  36
# Strength                         86
# Vision                           75
# Volleys                          73
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: H. Kane, dtype: object
# Age                              31
# Nationality                 England
# Overall                          84
# Acceleration                     62
# Aggression                       84
# Agility                          62
# Balance                          51
# Ball control                     63
# Composure                        75
# Crossing                         28
# Curve                            48
# Dribbling                        58
# Finishing                        56
# Free kick accuracy               27
# GK diving                         5
# GK handling                      12
# GK kicking                        9
# GK positioning                    5
# GK reflexes                      12
# Heading accuracy                 86
# Interceptions                    83
# Jumping                          82
# Long passing                     61
# Long shots                       66
# Marking                          84
# Penalties                        53
# Positioning                      45
# Reactions                        85
# Short passing                    65
# Shot power                       63
# Sliding tackle                   84
# Sprint speed                     63
# Stamina                          69
# Standing tackle                  85
# Strength                         80
# Vision                           56
# Volleys                          47
# Preferred Positions             CB
# Preferred Positions Type       Back
# Name: G. Cahill, dtype: object
# Age                              27
# Nationality                 England
# Overall                          83
# Acceleration                     86
# Aggression                       78
# Agility                          70
# Balance                          72
# Ball control                     76
# Composure                        75
# Crossing                         78
# Curve                            76
# Dribbling                        77
# Finishing                        51
# Free kick accuracy               71
# GK diving                        12
# GK handling                       6
# GK kicking                       16
# GK positioning                   15
# GK reflexes                       8
# Heading accuracy                 73
# Interceptions                    78
# Jumping                          83
# Long passing                     67
# Long shots                       68
# Marking                          79
# Penalties                        63
# Positioning                      66
# Reactions                        81
# Short passing                    75
# Shot power                       86
# Sliding tackle                   83
# Sprint speed                     93
# Stamina                          90
# Standing tackle                  84
# Strength                         77
# Vision                           69
# Volleys                          57
# Preferred Positions         RWB RB
# Preferred Positions Type       Back
# Name: K. Walker, dtype: object
# Age                              26
# Nationality                 England
# Overall                          82
# Acceleration                     80
# Aggression                       87
# Agility                          73
# Balance                          76
# Ball control                     76
# Composure                        73
# Crossing                         81
# Curve                            64
# Dribbling                        79
# Finishing                        57
# Free kick accuracy               57
# GK diving                        10
# GK handling                      11
# GK kicking                        8
# GK positioning                   13
# GK reflexes                      13
# Heading accuracy                 62
# Interceptions                    81
# Jumping                          75
# Long passing                     66
# Long shots                       69
# Marking                          82
# Penalties                        57
# Positioning                      68
# Reactions                        82
# Short passing                    76
# Shot power                       72
# Sliding tackle                   85
# Sprint speed                     81
# Stamina                          81
# Standing tackle                  84
# Strength                         74
# Vision                           73
# Volleys                          64
# Preferred Positions         LWB LB
# Preferred Positions Type       Back
# Name: D. Rose, dtype: object
# Age                                 23
# Nationality                    England
# Overall                             82
# Acceleration                        70
# Aggression                          90
# Agility                             56
# Balance                             40
# Ball control                        70
# Composure                           77
# Crossing                            67
# Curve                               54
# Dribbling                           66
# Finishing                           52
# Free kick accuracy                  77
# GK diving                           11
# GK handling                         14
# GK kicking                           6
# GK positioning                      13
# GK reflexes                          9
# Heading accuracy                    83
# Interceptions                       80
# Jumping                             77
# Long passing                        77
# Long shots                          72
# Marking                             79
# Penalties                           70
# Positioning                         53
# Reactions                           76
# Short passing                       76
# Shot power                          83
# Sliding tackle                      83
# Sprint speed                        74
# Stamina                             80
# Standing tackle                     82
# Strength                            87
# Vision                              66
# Volleys                             52
# Preferred Positions         CM CDM CB
# Preferred Positions Type          Back
# Name: E. Dier, dtype: object
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\BCX-JHB20\.conda\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Age                                 21
# Nationality                    England
# Overall                             84
# Acceleration                        77
# Aggression                          84
# Agility                             74
# Balance                             62
# Ball control                        85
# Composure                           86
# Crossing                            68
# Curve                               71
# Dribbling                           83
# Finishing                           84
# Free kick accuracy                  53
# GK diving                            7
# GK handling                          6
# GK kicking                           9
# GK positioning                      11
# GK reflexes                          8
# Heading accuracy                    75
# Interceptions                       67
# Jumping                             69
# Long passing                        76
# Long shots                          79
# Marking                             60
# Penalties                           68
# Positioning                         86
# Reactions                           85
# Short passing                       83
# Shot power                          77
# Sliding tackle                      57
# Sprint speed                        76
# Stamina                             89
# Standing tackle                     63
# Strength                            71
# Vision                              83
# Volleys                             76
# Preferred Positions         LM CF CAM
# Preferred Positions Type    Midfielder
# Name: D. Alli, dtype: object
# Age                                 29
# Nationality                    England
# Overall                             83
# Acceleration                        74
# Aggression                          74
# Agility                             83
# Balance                             76
# Ball control                        86
# Composure                           80
# Crossing                            74
# Curve                               77
# Dribbling                           85
# Finishing                           79
# Free kick accuracy                  66
# GK diving                            6
# GK handling                         15
# GK kicking                          14
# GK positioning                       8
# GK reflexes                         11
# Heading accuracy                    67
# Interceptions                       68
# Jumping                             73
# Long passing                        77
# Long shots                          72
# Marking                             60
# Penalties                           70
# Positioning                         77
# Reactions                           78
# Short passing                       86
# Shot power                          72
# Sliding tackle                      62
# Sprint speed                        72
# Stamina                             90
# Standing tackle                     67
# Strength                            67
# Vision                              83
# Volleys                             72
# Preferred Positions                CM
# Preferred Positions Type    Midfielder
# Name: A. Lallana, dtype: object
# Age                                 27
# Nationality                    England
# Overall                             82
# Acceleration                        73
# Aggression                          80
# Agility                             73
# Balance                             71
# Ball control                        80
# Composure                           78
# Crossing                            81
# Curve                               80
# Dribbling                           74
# Finishing                           67
# Free kick accuracy                  74
# GK diving                            7
# GK handling                         13
# GK kicking                           7
# GK positioning                       9
# GK reflexes                         13
# Heading accuracy                    65
# Interceptions                       79
# Jumping                             81
# Long passing                        83
# Long shots                          71
# Marking                             73
# Penalties                           64
# Positioning                         76
# Reactions                           79
# Short passing                       85
# Shot power                          75
# Sliding tackle                      76
# Sprint speed                        71
# Stamina                             93
# Standing tackle                     80
# Strength                            76
# Vision                              82
# Volleys                             72
# Preferred Positions            CM CDM
# Preferred Positions Type    Midfielder
# Name: J. Henderson, dtype: object
# Age                                 30
# Nationality                    England
# Overall                             82
# Acceleration                        59
# Aggression                          28
# Agility                             50
# Balance                             32
# Ball control                        20
# Composure                           68
# Crossing                            14
# Curve                               17
# Dribbling                           23
# Finishing                           14
# Free kick accuracy                  13
# GK diving                           83
# GK handling                         78
# GK kicking                          75
# GK positioning                      81
# GK reflexes                         83
# Heading accuracy                    10
# Interceptions                       25
# Jumping                             72
# Long passing                        35
# Long shots                          19
# Marking                             14
# Penalties                           48
# Positioning                         14
# Reactions                           77
# Short passing                       32
# Shot power                          65
# Sliding tackle                      13
# Sprint speed                        60
# Stamina                             28
# Standing tackle                     14
# Strength                            61
# Vision                              42
# Volleys                             19
# Preferred Positions                GK
# Preferred Positions Type    GoalKeeper
# Name: J. Hart, dtype: object
# Age                                22
# Nationality                   England
# Overall                            82
# Acceleration                       94
# Aggression                         34
# Agility                            91
# Balance                            92
# Ball control                       84
# Composure                          74
# Crossing                           73
# Curve                              64
# Dribbling                          85
# Finishing                          73
# Free kick accuracy                 49
# GK diving                          15
# GK handling                        12
# GK kicking                         12
# GK positioning                     15
# GK reflexes                         9
# Heading accuracy                   38
# Interceptions                      26
# Jumping                            60
# Long passing                       67
# Long shots                         70
# Marking                            48
# Penalties                          63
# Positioning                        81
# Reactions                          79
# Short passing                      81
# Shot power                         68
# Sliding tackle                     54
# Sprint speed                       92
# Stamina                            75
# Standing tackle                    58
# Strength                           64
# Vision                             75
# Volleys                            59
# Preferred Positions         LM RM RW
# Preferred Positions Type      Forward
# Name: R. Sterling, dtype: object
# Age                              31
# Nationality                 England
# Overall                          84
# Acceleration                     62
# Aggression                       84
# Agility                          62
# Balance                          51
# Ball control                     63
# Composure                        75
# Crossing                         28
# Curve                            48
# Dribbling                        58
# Finishing                        56
# Free kick accuracy               27
# GK diving                         5
# GK handling                      12
# GK kicking                        9
# GK positioning                    5
# GK reflexes                      12
# Heading accuracy                 86
# Interceptions                    83
# Jumping                          82
# Long passing                     61
# Long shots                       66
# Marking                          84
# Penalties                        53
# Positioning                      45
# Reactions                        85
# Short passing                    65
# Shot power                       63
# Sliding tackle                   84
# Sprint speed                     63
# Stamina                          69
# Standing tackle                  85
# Strength                         80
# Vision                           56
# Volleys                          47
# Preferred Positions             CB
# Preferred Positions Type       Back
# Name: G. Cahill, dtype: object
# Age                              27
# Nationality                 England
# Overall                          83
# Acceleration                     86
# Aggression                       78
# Agility                          70
# Balance                          72
# Ball control                     76
# Composure                        75
# Crossing                         78
# Curve                            76
# Dribbling                        77
# Finishing                        51
# Free kick accuracy               71
# GK diving                        12
# GK handling                       6
# GK kicking                       16
# GK positioning                   15
# GK reflexes                       8
# Heading accuracy                 73
# Interceptions                    78
# Jumping                          83
# Long passing                     67
# Long shots                       68
# Marking                          79
# Penalties                        63
# Positioning                      66
# Reactions                        81
# Short passing                    75
# Shot power                       86
# Sliding tackle                   83
# Sprint speed                     93
# Stamina                          90
# Standing tackle                  84
# Strength                         77
# Vision                           69
# Volleys                          57
# Preferred Positions         RWB RB
# Preferred Positions Type       Back
# Name: K. Walker, dtype: object
# Age                              26
# Nationality                 England
# Overall                          82
# Acceleration                     80
# Aggression                       87
# Agility                          73
# Balance                          76
# Ball control                     76
# Composure                        73
# Crossing                         81
# Curve                            64
# Dribbling                        79
# Finishing                        57
# Free kick accuracy               57
# GK diving                        10
# GK handling                      11
# GK kicking                        8
# GK positioning                   13
# GK reflexes                      13
# Heading accuracy                 62
# Interceptions                    81
# Jumping                          75
# Long passing                     66
# Long shots                       69
# Marking                          82
# Penalties                        57
# Positioning                      68
# Reactions                        82
# Short passing                    76
# Shot power                       72
# Sliding tackle                   85
# Sprint speed                     81
# Stamina                          81
# Standing tackle                  84
# Strength                         74
# Vision                           73
# Volleys                          64
# Preferred Positions         LWB LB
# Preferred Positions Type       Back
# Name: D. Rose, dtype: object
# Age                                 23
# Nationality                    England
# Overall                             82
# Acceleration                        70
# Aggression                          90
# Agility                             56
# Balance                             40
# Ball control                        70
# Composure                           77
# Crossing                            67
# Curve                               54
# Dribbling                           66
# Finishing                           52
# Free kick accuracy                  77
# GK diving                           11
# GK handling                         14
# GK kicking                           6
# GK positioning                      13
# GK reflexes                          9
# Heading accuracy                    83
# Interceptions                       80
# Jumping                             77
# Long passing                        77
# Long shots                          72
# Marking                             79
# Penalties                           70
# Positioning                         53
# Reactions                           76
# Short passing                       76
# Shot power                          83
# Sliding tackle                      83
# Sprint speed                        74
# Stamina                             80
# Standing tackle                     82
# Strength                            87
# Vision                              66
# Volleys                             52
# Preferred Positions         CM CDM CB
# Preferred Positions Type          Back
# Name: E. Dier, dtype: object
# Age                                 21
# Nationality                    England
# Overall                             84
# Acceleration                        77
# Aggression                          84
# Agility                             74
# Balance                             62
# Ball control                        85
# Composure                           86
# Crossing                            68
# Curve                               71
# Dribbling                           83
# Finishing                           84
# Free kick accuracy                  53
# GK diving                            7
# GK handling                          6
# GK kicking                           9
# GK positioning                      11
# GK reflexes                          8
# Heading accuracy                    75
# Interceptions                       67
# Jumping                             69
# Long passing                        76
# Long shots                          79
# Marking                             60
# Penalties                           68
# Positioning                         86
# Reactions                           85
# Short passing                       83
# Shot power                          77
# Sliding tackle                      57
# Sprint speed                        76
# Stamina                             89
# Standing tackle                     63
# Strength                            71
# Vision                              83
# Volleys                             76
# Preferred Positions         LM CF CAM
# Preferred Positions Type    Midfielder
# Name: D. Alli, dtype: object
# Age                                 29
# Nationality                    England
# Overall                             83
# Acceleration                        74
# Aggression                          74
# Agility                             83
# Balance                             76
# Ball control                        86
# Composure                           80
# Crossing                            74
# Curve                               77
# Dribbling                           85
# Finishing                           79
# Free kick accuracy                  66
# GK diving                            6
# GK handling                         15
# GK kicking                          14
# GK positioning                       8
# GK reflexes                         11
# Heading accuracy                    67
# Interceptions                       68
# Jumping                             73
# Long passing                        77
# Long shots                          72
# Marking                             60
# Penalties                           70
# Positioning                         77
# Reactions                           78
# Short passing                       86
# Shot power                          72
# Sliding tackle                      62
# Sprint speed                        72
# Stamina                             90
# Standing tackle                     67
# Strength                            67
# Vision                              83
# Volleys                             72
# Preferred Positions                CM
# Preferred Positions Type    Midfielder
# Name: A. Lallana, dtype: object
# Age                                 27
# Nationality                    England
# Overall                             82
# Acceleration                        73
# Aggression                          80
# Agility                             73
# Balance                             71
# Ball control                        80
# Composure                           78
# Crossing                            81
# Curve                               80
# Dribbling                           74
# Finishing                           67
# Free kick accuracy                  74
# GK diving                            7
# GK handling                         13
# GK kicking                           7
# GK positioning                       9
# GK reflexes                         13
# Heading accuracy                    65
# Interceptions                       79
# Jumping                             81
# Long passing                        83
# Long shots                          71
# Marking                             73
# Penalties                           64
# Positioning                         76
# Reactions                           79
# Short passing                       85
# Shot power                          75
# Sliding tackle                      76
# Sprint speed                        71
# Stamina                             93
# Standing tackle                     80
# Strength                            76
# Vision                              82
# Volleys                             72
# Preferred Positions            CM CDM
# Preferred Positions Type    Midfielder
# Name: J. Henderson, dtype: object
# Age                                 30
# Nationality                    England
# Overall                             82
# Acceleration                        59
# Aggression                          28
# Agility                             50
# Balance                             32
# Ball control                        20
# Composure                           68
# Crossing                            14
# Curve                               17
# Dribbling                           23
# Finishing                           14
# Free kick accuracy                  13
# GK diving                           83
# GK handling                         78
# GK kicking                          75
# GK positioning                      81
# GK reflexes                         83
# Heading accuracy                    10
# Interceptions                       25
# Jumping                             72
# Long passing                        35
# Long shots                          19
# Marking                             14
# Penalties                           48
# Positioning                         14
# Reactions                           77
# Short passing                       32
# Shot power                          65
# Sliding tackle                      13
# Sprint speed                        60
# Stamina                             28
# Standing tackle                     14
# Strength                            61
# Vision                              42
# Volleys                             19
# Preferred Positions                GK
# Preferred Positions Type    GoalKeeper
# Name: J. Hart, dtype: object
# Age                              27
# Nationality                 England
# Overall                          82
# Acceleration                     74
# Aggression                       60
# Agility                          75
# Balance                          64
# Ball control                     81
# Composure                        81
# Crossing                         62
# Curve                            62
# Dribbling                        80
# Finishing                        83
# Free kick accuracy               68
# GK diving                         7
# GK handling                      15
# GK kicking                        9
# GK positioning                    5
# GK reflexes                      13
# Heading accuracy                 73
# Interceptions                    22
# Jumping                          72
# Long passing                     62
# Long shots                       80
# Marking                          15
# Penalties                        75
# Positioning                      84
# Reactions                        82
# Short passing                    74
# Shot power                       83
# Sliding tackle                   12
# Sprint speed                     78
# Stamina                          68
# Standing tackle                  24
# Strength                         71
# Vision                           74
# Volleys                          75
# Preferred Positions             ST
# Preferred Positions Type    Forward
# Name: D. Sturridge, dtype: object
# Age                              31
# Nationality                 England
# Overall                          84
# Acceleration                     62
# Aggression                       84
# Agility                          62
# Balance                          51
# Ball control                     63
# Composure                        75
# Crossing                         28
# Curve                            48
# Dribbling                        58
# Finishing                        56
# Free kick accuracy               27
# GK diving                         5
# GK handling                      12
# GK kicking                        9
# GK positioning                    5
# GK reflexes                      12
# Heading accuracy                 86
# Interceptions                    83
# Jumping                          82
# Long passing                     61
# Long shots                       66
# Marking                          84
# Penalties                        53
# Positioning                      45
# Reactions                        85
# Short passing                    65
# Shot power                       63
# Sliding tackle                   84
# Sprint speed                     63
# Stamina                          69
# Standing tackle                  85
# Strength                         80
# Vision                           56
# Volleys                          47
# Preferred Positions             CB
# Preferred Positions Type       Back
# Name: G. Cahill, dtype: object
# Age                              27
# Nationality                 England
# Overall                          83
# Acceleration                     86
# Aggression                       78
# Agility                          70
# Balance                          72
# Ball control                     76
# Composure                        75
# Crossing                         78
# Curve                            76
# Dribbling                        77
# Finishing                        51
# Free kick accuracy               71
# GK diving                        12
# GK handling                       6
# GK kicking                       16
# GK positioning                   15
# GK reflexes                       8
# Heading accuracy                 73
# Interceptions                    78
# Jumping                          83
# Long passing                     67
# Long shots                       68
# Marking                          79
# Penalties                        63
# Positioning                      66
# Reactions                        81
# Short passing                    75
# Shot power                       86
# Sliding tackle                   83
# Sprint speed                     93
# Stamina                          90
# Standing tackle                  84
# Strength                         77
# Vision                           69
# Volleys                          57
# Preferred Positions         RWB RB
# Preferred Positions Type       Back
# Name: K. Walker, dtype: object
# Age                              26
# Nationality                 England
# Overall                          82
# Acceleration                     80
# Aggression                       87
# Agility                          73
# Balance                          76
# Ball control                     76
# Composure                        73
# Crossing                         81
# Curve                            64
# Dribbling                        79
# Finishing                        57
# Free kick accuracy               57
# GK diving                        10
# GK handling                      11
# GK kicking                        8
# GK positioning                   13
# GK reflexes                      13
# Heading accuracy                 62
# Interceptions                    81
# Jumping                          75
# Long passing                     66
# Long shots                       69
# Marking                          82
# Penalties                        57
# Positioning                      68
# Reactions                        82
# Short passing                    76
# Shot power                       72
# Sliding tackle                   85
# Sprint speed                     81
# Stamina                          81
# Standing tackle                  84
# Strength                         74
# Vision                           73
# Volleys                          64
# Preferred Positions         LWB LB
# Preferred Positions Type       Back
# Name: D. Rose, dtype: object
# Age                                 23
# Nationality                    England
# Overall                             82
# Acceleration                        70
# Aggression                          90
# Agility                             56
# Balance                             40
# Ball control                        70
# Composure                           77
# Crossing                            67
# Curve                               54
# Dribbling                           66
# Finishing                           52
# Free kick accuracy                  77
# GK diving                           11
# GK handling                         14
# GK kicking                           6
# GK positioning                      13
# GK reflexes                          9
# Heading accuracy                    83
# Interceptions                       80
# Jumping                             77
# Long passing                        77
# Long shots                          72
# Marking                             79
# Penalties                           70
# Positioning                         53
# Reactions                           76
# Short passing                       76
# Shot power                          83
# Sliding tackle                      83
# Sprint speed                        74
# Stamina                             80
# Standing tackle                     82
# Strength                            87
# Vision                              66
# Volleys                             52
# Preferred Positions         CM CDM CB
# Preferred Positions Type          Back
# Name: E. Dier, dtype: object
# Age                                 21
# Nationality                    England
# Overall                             84
# Acceleration                        77
# Aggression                          84
# Agility                             74
# Balance                             62
# Ball control                        85
# Composure                           86
# Crossing                            68
# Curve                               71
# Dribbling                           83
# Finishing                           84
# Free kick accuracy                  53
# GK diving                            7
# GK handling                          6
# GK kicking                           9
# GK positioning                      11
# GK reflexes                          8
# Heading accuracy                    75
# Interceptions                       67
# Jumping                             69
# Long passing                        76
# Long shots                          79
# Marking                             60
# Penalties                           68
# Positioning                         86
# Reactions                           85
# Short passing                       83
# Shot power                          77
# Sliding tackle                      57
# Sprint speed                        76
# Stamina                             89
# Standing tackle                     63
# Strength                            71
# Vision                              83
# Volleys                             76
# Preferred Positions         LM CF CAM
# Preferred Positions Type    Midfielder
# Name: D. Alli, dtype: object
# Age                                 29
# Nationality                    England
# Overall                             83
# Acceleration                        74
# Aggression                          74
# Agility                             83
# Balance                             76
# Ball control                        86
# Composure                           80
# Crossing                            74
# Curve                               77
# Dribbling                           85
# Finishing                           79
# Free kick accuracy                  66
# GK diving                            6
# GK handling                         15
# GK kicking                          14
# GK positioning                       8
# GK reflexes                         11
# Heading accuracy                    67
# Interceptions                       68
# Jumping                             73
# Long passing                        77
# Long shots                          72
# Marking                             60
# Penalties                           70
# Positioning                         77
# Reactions                           78
# Short passing                       86
# Shot power                          72
# Sliding tackle                      62
# Sprint speed                        72
# Stamina                             90
# Standing tackle                     67
# Strength                            67
# Vision                              83
# Volleys                             72
# Preferred Positions                CM
# Preferred Positions Type    Midfielder
# Name: A. Lallana, dtype: object
# Age                                 27
# Nationality                    England
# Overall                             82
# Acceleration                        73
# Aggression                          80
# Agility                             73
# Balance                             71
# Ball control                        80
# Composure                           78
# Crossing                            81
# Curve                               80
# Dribbling                           74
# Finishing                           67
# Free kick accuracy                  74
# GK diving                            7
# GK handling                         13
# GK kicking                           7
# GK positioning                       9
# GK reflexes                         13
# Heading accuracy                    65
# Interceptions                       79
# Jumping                             81
# Long passing                        83
# Long shots                          71
# Marking                             73
# Penalties                           64
# Positioning                         76
# Reactions                           79
# Short passing                       85
# Shot power                          75
# Sliding tackle                      76
# Sprint speed                        71
# Stamina                             93
# Standing tackle                     80
# Strength                            76
# Vision                              82
# Volleys                             72
# Preferred Positions            CM CDM
# Preferred Positions Type    Midfielder
# Name: J. Henderson, dtype: object
# Age                                 30
# Nationality                    England
# Overall                             82
# Acceleration                        59
# Aggression                          28
# Agility                             50
# Balance                             32
# Ball control                        20
# Composure                           68
# Crossing                            14
# Curve                               17
# Dribbling                           23
# Finishing                           14
# Free kick accuracy                  13
# GK diving                           83
# GK handling                         78
# GK kicking                          75
# GK positioning                      81
# GK reflexes                         83
# Heading accuracy                    10
# Interceptions                       25
# Jumping                             72
# Long passing                        35
# Long shots                          19
# Marking                             14
# Penalties                           48
# Positioning                         14
# Reactions                           77
# Short passing                       32
# Shot power                          65
# Sliding tackle                      13
# Sprint speed                        60
# Stamina                             28
# Standing tackle                     14
# Strength                            61
# Vision                              42
# Volleys                             19
# Preferred Positions                GK
# Preferred Positions Type    GoalKeeper
# Name: J. Hart, dtype: object
